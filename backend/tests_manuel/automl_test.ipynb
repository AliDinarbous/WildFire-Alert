# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("Project root:", PROJECT_ROOT)
print("sys.path:", sys.path[:3])
# Out:
# Project root: /home/ali/WildFire-Alert/backend
# sys.path: ['/home/ali/WildFire-Alert/backend', '/home/ali/miniconda3/envs/wildfire/lib/python311.zip', '/home/ali/miniconda3/envs/wildfire/lib/python3.11']

# %%
from automl.automl import (fit, eval, predict)

# %%
DATASET_PATH = "/home/ali/WildFire-Alert/backend/data/dataset"


assert os.path.exists(DATASET_PATH), f"Dataset introuvable : {DATASET_PATH}"
print("Dataset trouvé :", DATASET_PATH)
# Out:
# Dataset trouvé : /home/ali/WildFire-Alert/backend/data/dataset

# %%
for root, dirs, files in os.walk(DATASET_PATH):
    depth = root.replace(DATASET_PATH, '').count(os.sep)
    indent = '  ' * depth
    print(f"{indent}{os.path.basename(root)}/")
    if depth >= 3:  
        subindent = '  ' * (depth + 1)
        print(f"{subindent}[{len(files)} fichiers]")
        dirs.clear()
# Out:
# dataset/
#   Archive/
#     test/
#       nowildfire/
#         [5640 fichiers]
#       wildfire/
#         [6960 fichiers]
#     train/
#       nowildfire/
#         [29000 fichiers]
#       wildfire/
#         [31500 fichiers]
#     valid/
#       nowildfire/
#         [5640 fichiers]
#       wildfire/
#         [6960 fichiers]

# %%
model = fit(DATASET_PATH, True)
# Out:
# Train: (4000, 72), Test: (850, 72), Dev: (850, 72)
# Training set size: 4000
# Validation set size: 850
# Test set size: 850
# Problem type: type_enum.BINARY_CLASSIFICATION
# Training 2 models...
#   [1/2] Training RandomForestClassifier(DecisionTreeClassifier)... Score: 0.9865
#   [2/2] Training GradientBoostingClassifier... Score: 0.9890
#
# Best model: GradientBoostingClassifier (score: 0.9890)
# Best model selected: GradientBoostingClassifier
# optimize model
# Model training completed.
# Optimal hyperparameters: {'top_5_params': [OrderedDict([('learning_rate', 0.15339540888700345), ('max_depth', 4), ('min_samples_leaf', 7), ('min_samples_split', 2), ('n_estimators', 212), ('subsample', 0.842376338549186)]), OrderedDict([('learning_rate', 0.25), ('max_depth', 4), ('min_samples_leaf', 7), ('min_samples_split', 7), ('n_estimators', 235), ('subsample', 0.65)]), OrderedDict([('learning_rate', 0.15377067149801488), ('max_depth', 5), ('min_samples_leaf', 7), ('min_samples_split', 7), ('n_estimators', 200), ('subsample', 0.931503242554655)]), OrderedDict([('learning_rate', 0.19636658220530392), ('max_depth', 4), ('min_samples_leaf', 1), ('min_samples_split', 2), ('n_estimators', 217), ('subsample', 0.7994519962737903)]), OrderedDict([('learning_rate', 0.1816932761665904), ('max_depth', 4), ('min_samples_leaf', 7), ('min_samples_split', 2), ('n_estimators', 250), ('subsample', 0.9191871370738884)])], 'best_from_bayes': OrderedDict([('learning_rate', 0.15339540888700345), ('max_depth', 4), ('min_samples_leaf', 7), ('min_samples_split', 2), ('n_estimators', 212), ('subsample', 0.842376338549186)])}

# %%
metrics = eval(verbose=True)
# Out:
# === Classification Metrics ===
# Accuracy: 0.9941
# F1-Score (macro): 0.9941
# F1-Score (micro): 0.9941
#
# Confusion Matrix:
# [[424   1]
#  [  4 421]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       425
#            1       1.00      0.99      0.99       425
#
#     accuracy                           0.99       850
#    macro avg       0.99      0.99      0.99       850
# weighted avg       0.99      0.99      0.99       850
